# %% [markdown]
# # Lab 1 Python Tutorial
#
# Hello and welcome to Python. A Jupyter notebook is a way of executing a series of python commands in distinct cells, while also providing space for "markdown" cells to explain what you're doing in words/equations. When you're in a cell, Ctrl+Enter will execute all of the python commands in the cell. Use your arrow keys to navigate between cells. To create a new cell, either click on the + symbol in the menu up top, or if you are highlited on a particular cell (NOT the text, but the cell itself), simply type "b."

# %% [markdown]
# ## basic arithmetic, python as "desk calculator"

# %%
# This is a comment, since I started the line with "#"
# Python can do basic arithmetic. Addition is with a (surprise) "plus" sign.
2 + 5
# Out:
# 7

# %%
# By default, just typing a variable at the end of a cell prints the result, but you can make sure by calling
# the "print" function
print(2 + 5)
# Out:
# 7

# %%
# Multiplication is with a star
2 * 5
# Out:
# 10

# %%
# Division is with a /
2 / 5
# Out:
# 0.4

# %%
# Exponentiation is with a double star
2 ** 5
# Out:
# 32

# %%
# Not everything has to be an integer, Python accommodates "floating point" representations
# as well as integers
2.3 * 4.5
# Out:
# 10.35

# %%
print(type(2))
print(type(2.3))
# Out:
# <class 'int'>
# <class 'float'>

# %% [markdown]
# ## variables
#
# What is a variable?
#
# A variable is used to store informration to be referenced and manipulated in a
# computer program. This "information" can be as simple as one number, or a list of numbers (e.g. vector/matrix) or other more complex structures (like a list of other information, a dictionary, a string). We will start with just numbers for now.
#
# What are variables for?
# * Provide a way of labeling data with a descriptive name, so our
# programs can be understood more clearly by the reader and ourselves.
# * It is helpful to think of variables as containers that hold
# information.  Their sole purpose is to label and store data in memory. This data can then be used throughout your program.
#
# To create a new variable, enter the variable name in the command window,
# followed by an equal sign (=) and the value you want to assign to the
# variable. We can then apply the operations we learned to those variables. Try it out in a cell below!

# %%
# Examples
a = 2
b = 5
print(a + b)

electrical_bill = 60
gas_bill = 30
total_utilities = electrical_bill + gas_bill
print(total_utilities)
# Out:
# 7
# 90

# %%
#different from MATLAB, python allows us to define variables in a compact way
a, b, c = 7, 8, 9
print(a+b+c)
# Out:
# 24

# %%
#try it out yourself, define some variables and do basic arithmetic with them

# %% [markdown]
# ## life-changing tip
# According to good coding practice, your variable names should be long and descriptive, so when you read through it you know exactly what each variable represents. (See example above with "electrical_bill".) However, a potential downside of this is the need to meticously type out their names without typos---what do we do about this?
#
# The solution: use the "tab" key to autocomplete variable names. This saves time while guaranteeing you avoid typos in variable names. Any variable that already exists and is compatible with what you've typed so far will appear as an option.

# %%
# Ex: start typing "electrical_bill" and then press Tab
electrical_bill
# Out:
# 60

# %%
# Multiple compatible auto-competions
variable_1 = 10
variable_2 = 20
#Type "variable_1 + variable_2" and try to use Tab autocomplete, see what happens
variable_1 + variable_2
# Out:
# 30

# %% [markdown]
# ## other things that can be variables: lists
# Really any python "object" can be stored in a variable. An object is any discrete thing in python that gets referred to by a single variable. Numbers are just one example out of many. We'll show one other basic type of python object (again, among countless others): the list.
#
# ### List
# A list is simply an ordered list of other python objects. To define a list, we put the contents in square brackets [] with commas separating the list contents. Anything can go in the list---they don't have to be a similar kind of object.

# %%
# List examples
my_list = [2, 3]
my_meta_list = [2, 3, [2, 3]] # a list containing a list! scandalous!
# can equivalently define by
my_meta_list = [2, 3, my_list]

# %%
# To access an element of a list, use square brackets after the list with an index
# One of the big differences between Matlab and Python is that Python starts all indexing
# at 0.
print(my_list[0] + my_list[1])
# Out:
# 5

# %%
# If you try to access an element that doens't exist, python throws an error
my_list[2]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-7-ae289e2bd1a1> in <module>
#       1 # If you try to access an element that doens't exist, python throws an error
# ----> 2 my_list[2]
#
# IndexError: list index out of range

# %%
# Fun trick: if you want the last element of a list, use "-1". Or more generally,
# you can index negatively from the end of a list by counting out negative numbers
my_long_list = [3, 4, 6, -2, 4, 9]
print(my_long_list[-1])
print(my_long_list[-2])
# Out:
# 9
# 4

# %%
#Remove or add elements
my_list_long = list(range(10,30,3)) #first lets create a long list
print(my_list_long)

my_list_long.remove(10) #remove an element from a list
print(my_list_long)

my_list_long.pop(0) #remove the first element
print(my_list_long)

my_list_long.append(3)
print(my_list_long)
# Out:
# [10, 13, 16, 19, 22, 25, 28]
# [13, 16, 19, 22, 25, 28]
# [16, 19, 22, 25, 28]
# [16, 19, 22, 25, 28, 3]

# %%
#sublists
my_lists = [[1,2],[3,4]]
print(my_lists[0])
print(my_lists[1])
# Out:
# [1, 2]
# [3, 4]

# %% [markdown]
# ### warning: lists are NOT vectors
# We've learned in class so far that a vector is an ordered list of numbers, and you can add them together and multiply them by scalars. However, this is a *very* special case of a list, in which the elements are each numbers. Because a python list is such a general concept, it can't be made to follow these rules that are specific to numbers. In fact, if you try to do the math from class on python lists, you will get the wrong answers!

# %%
# Examples of "list addition"
list_1 = [2, 3]
list_2 = [3, 5]
print(list_1 + list_2)
# Question: if we were doing linear algebra from class, what would we want (2, 3) + (3, 5) to be? Is this it?
# Out:
# [2, 3, 3, 5]

# %%
list_3 = [2, 4, 5]
list_4 = [1, 0]
print(list_3 + list_4)
# Out:
# [2, 4, 5, 1, 0]

# %%
# Example of "list mulitplication"
print(list_1 * 3)
# Out:
# [2, 3, 2, 3, 2, 3]

# %%
# Create your own examples and try out list addition and mulitplication by numbers.
# Can you figure out what these operations do?

# ANSWER: List addition "concatenates" the lists, while list multiplication duplicates the elements
# some number of times

# %% [markdown]
# ### So how do we do the math from class?
# To cover this, we will have to talk about python packages...

# %% [markdown]
# ## python packages
# We've gone over basic arthimetic. What if I wanted to do something a little fancier, like take a square root, or use the number pi? Well I've got bad news: **we have already surpassed the complexity of basic python**.

# %%
sqrt(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-ef2dc5896f23> in <module>
# ----> 1 sqrt(5)
#
# NameError: name 'sqrt' is not defined

# %%
pi
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-f84ab820532c> in <module>
# ----> 1 pi
#
# NameError: name 'pi' is not defined

# %% [markdown]
# Basic python is really quite simple. What makes python so powerful is that there are a truly enormous number of **packages** you can access to bring in specifically the features that you need. By installing Anaconda, you didn't just install the python language itself, but also a large number of commonly used packages in scientific and other types of programming.
#
# ## accessing packages
#
# Within one session of python, not every available package you have on your computer is ready to use immediately. You wouldn't even want this, as keywords from different packages would conflict. Instead, you import within one python session (e.g. this jupyter notebook you're running) the specific packages you need. We'll show an example for the most important python package we'll use: numpy. Numpy is a package that contains all relevant functions for basic and advanced math, including vectors, matrices, linear algebra, etc.

# %%
import numpy as np

# %% [markdown]
# "numpy" is the name of the package, and the "import ___ as __ " syntax gives it a nickname that's shorter to type. Now it exists as a variable "np" in our jupyter notebook, and we can access useful contents from it. A lot of what we do from now on, everything has to have "np." in front of it to specify we are using some function or object inherited from the numpy package.

# %%
# What all is in it?
dir(np)
# Wow that's a lot
# Out:
# ['ALLOW_THREADS',
#  'AxisError',
#  'BUFSIZE',
#  'CLIP',
#  'ComplexWarning',
#  'DataSource',
#  'ERR_CALL',
#  'ERR_DEFAULT',
#  'ERR_IGNORE',
#  'ERR_LOG',
#  'ERR_PRINT',
#  'ERR_RAISE',
#  'ERR_WARN',
#  'FLOATING_POINT_SUPPORT',
#  'FPE_DIVIDEBYZERO',
#  'FPE_INVALID',
#  'FPE_OVERFLOW',
#  'FPE_UNDERFLOW',
#  'False_',
#  'Inf',
#  'Infinity',
#  'MAXDIMS',
#  'MAY_SHARE_BOUNDS',
#  'MAY_SHARE_EXACT',
#  'MachAr',
#  'ModuleDeprecationWarning',
#  'NAN',
#  'NINF',
#  'NZERO',
#  'NaN',
#  'PINF',
#  'PZERO',
#  'RAISE',
#  'RankWarning',
#  'SHIFT_DIVIDEBYZERO',
#  'SHIFT_INVALID',
#  'SHIFT_OVERFLOW',
#  'SHIFT_UNDERFLOW',
#  'ScalarType',
#  'Tester',
#  'TooHardError',
#  'True_',
#  'UFUNC_BUFSIZE_DEFAULT',
#  'UFUNC_PYVALS_NAME',
#  'VisibleDeprecationWarning',
#  'WRAP',
#  '_NoValue',
#  '_UFUNC_API',
#  '__NUMPY_SETUP__',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__config__',
#  '__dir__',
#  '__doc__',
#  '__file__',
#  '__getattr__',
# ...

# %%
# Phew we can take square roots and access pi if we need
np.sqrt(5)
# Out:
# 2.23606797749979

# %%
np.pi
# Out:
# 3.141592653589793

# %% [markdown]
# ## numpy arrays
# The "array" is the fundamental object of numpy. It is like a list, in that it's an ordered list of numbers. But unlike a list, the contents *have* to be numbers (not other lists, not strings, not any other random python thing). And also unlike a list, the addition and multiplication operations follow the rules of linear algebra we learned in class.

# %%
# Creating an array by calling np.array() function wiht a *list* as the argument
my_array = np.array([1, 3])

# %%
# Exercise: Create 2 arrays and add them together. What do you get? What if they have the same
# number of entries? What if they do not?

A = np.array([0, 4])
B = np.array([2, 3])
print(A + B)

C = np.array([3, 1, 0])
print(A + C)
# Out:
# [2 7]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-6b2c906fc243> in <module>
#       7
#       8 C = np.array([3, 1, 0])
# ----> 9 print(A + C)
#
# ValueError: operands could not be broadcast together with shapes (2,) (3,)

# %%
# Exercise: Define an array and a scalar of your choice. Multiply them together. Does this
# make sense with what we learned in class?

alpha = 0.5
u = np.array([2, 3])
print(alpha * u)
# Out:
# [1.  1.5]

# %% [markdown]
# # elementwise operations
# Numpy arrays are flexible, and you can have numpy perform an operation on all the entries at once. Scalar multiplication above is one example of this, but almost any function can be applied "element-wise" to a numpy array.

# %%
# Example: taking the square root of several numbers at once
my_array = np.array([4, 9, 25])
np.sqrt(my_array)
# Out:
# array([2., 3., 5.])

# %%
# We can also sum the entries of an array to get a scalar
my_array.sum()
# Out:
# 38

# %%
# Alternatively, we can also write
np.sum(my_array)
# Out:
# 38

# %%
# Exercise: Play with the np.arange(start, end) function for a bit until you know how it works. Then, using it
# and the np.sum() function, calculate the sum of the integers 1 - 100.

print(np.sum(np.arange(1, 101)))
# Out:
# 5050

# %%
# Exercise: Using the np.square(), np.sum(), and np.sqrt() functions, calculate the length of a vector you define.

u = np.array([1, 4, -2, 5])
print(np.sqrt(np.sum(np.square(u))))
# Out:
# 6.782329983125268

# %% [markdown]
# ## For loops
# A for-loop is a statement for specifying iteration, which allows code to be executed repeatedly.

# %%
#an example
for i in range(len(my_array)): #don't miss the colon
    print(my_array[i])
    
#OR
for i in my_array: #directly accessing the elements
    print(i)
# Out:
# 4
# 9
# 25
# 4
# 9
# 25

# %% [markdown]
# ## If else statement

# %%
temperature = float(input('Weather (in celsius): '))
if temperature <= 22:
    print('It''s too cold!')
elif 23 <= temperature <=27:
    print('Great weather!')
else:
    print('It''s too hot!')
# Out:
# Weather (in celsius): 40
# Its too hot!

# %% [markdown]
# ## plotting
# You can't take square roots in basic python, and you can't plot stuff either. To access this power, you must import the highly reputed matplotlib.pyplot package

# %%
import matplotlib.pyplot as plt #Do you recognize this syntax from numpy import above?
#(The following is just a magic keyword for jupyter notebook, don't worry about it)
# %matplotlib notebook

# %%
# Plotting a vector
my_vector = np.array([2, 3, 6, -1])
plt.figure()
plt.plot(my_vector)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# This above just plots the entries 0 - 3 of the vector, which are 2, 3, 6, and -1. This makes the X-axis quite boring--it's just the indices of the entires--while the Y-axis contains the actual information about the vector we're plotting.

# %%
# Same plot as above but with dots instead of connecting lines.
plt.figure()
plt.plot(my_vector, '.')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Example with x-axis values specified. What if x and y didn't have the same shape?
x = np.array([-2, 0, -3, 1])
y = np.array([0, 1, 3, 4])
plt.figure()
plt.plot(x, y, '.')
plt.xlim([-5, 5])
plt.ylim([-5, 5])
# Out:
# <img src="data:image/png;base64,..." width="640">
# (-5, 5)

# %%
# Example: multiple plots on one figure
theta = np.arange(0, np.pi, 0.01)
x = np.cos(theta)
y = np.sin(theta)
plt.figure()
plt.plot(x)
plt.plot(y)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Exercise: Start exploring the vast galaxy of arguments that plt.plot() allows you to pass to it. An "argument"
# is just any keyword=value you plug into plt.plot(), for example plt.plot(x, color='C0'). Plot more
# vectors of various sizes, while specifying say the color, linewidth, linestyle, alpha, etc.
v = np.random.normal(0, 1, 100)
plt.figure()
plt.plot(v, color='C3', linestyle='--', alpha=0.7)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # fun tip
# If you press Shift-Tab while your cursor is inside the parentheses of a function, Jupyter notebook will show you the documentation so you can quickly learn about what types of keywords exist that you can specify.

# %%
# Exercise: define a 2-D vector u and another 2-D vector v with whatever entries you want. Then add them
# up as we did in class to get u + v. Plot all 3 vectors as *arrows* in the plane and geometrically show
# vector addition by translation both u and v "tip to tail".
# (Note: this is a bit tricky, as you have to plot each vector's connection from the origin to its coordinates.
# How would you do this? Hint: you can plot lists, not just arrays. First try just plotting a line, then see
# if you can use Google to figure out how to decorate your solution with an arrowhead).

#Define vectors

u = np.array([-2, 4])
v = np.array([1, 6])
w = u + v

#Just plotting lines
plt.figure()
plt.plot([0, u[0]], [0, u[1]], color='C0')
plt.plot([0, v[0]], [0, v[1]], color='C1')
plt.plot([v[0], v[0] + u[0]], [v[1], v[1] + u[1]], color='C0')
plt.plot([u[0], u[0] + v[0]], [u[1], u[1] + v[1]], color='C1')
plt.plot([0, w[0]], [0, w[1]], color='C2')
plt.axhline(y=0, color='k', linestyle='--')
plt.axvline(x=0, color='k', linestyle='--')
plt.xlim([-11, 11])
plt.ylim([-11, 11])

#For the arrowheads, see if you can figu
plt.figure()
plt.arrow(0, 0, u[0], u[1], width=0.05, color='C1')
plt.xlim([-10, 10])
plt.ylim([-10, 10])
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# (-10, 10)
